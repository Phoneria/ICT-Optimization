# %% [markdown]
# # IMPORT LIBS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import timedelta
import time
import mplfinance as mpf
import os
import datetime

# %% [markdown]
# # CONSTANTS

# %%
GRAPH_EXTEND = 10
RISK_REWARD_RATIO = 1
POSITION_TP_SL_RANGE = 20
CISD_CHECK_RANGE = 11

# %% [markdown]
# # Preprocess

# %%
# Dataset path
path1 = r"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\Das Reich\AlgoV2\Datasets\NASDAQ\USATECH_ADJUSTED_30.09.2021-21.09.2024.csv"
path2 = r"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\Das Reich\AlgoV2\Datasets\NASDAQ\USATECH_ADJUSTED_29.09.2018-29.09.2021.csv"
path3 = r"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\Das Reich\AlgoV2\Datasets\NASDAQ\USATECH.IDXUSD_Candlestick_1_M_BID_23.09.2024-30.11.2024.csv"
# Read the dataset

df = pd.read_csv(path1)

# # 'Local time' kolonundaki zaman dilimini temizle ve datetime formatına dönüştür
# df['Local time'] = df['Local time'].str.split(' GMT').str[0]  # ' GMT+0300' kısmını çıkarır
# df['Local time'] = pd.to_datetime(df['Local time'], format='%d.%m.%Y %H:%M:%S.%f')  # Doğru formatı belirtin
df['Local time'] = pd.to_datetime(df['Local time'], format='%Y-%m-%d %H:%M:%S')

# Set the index to 'Local time' for mplfinance compatibility
df_chart = df.copy()
df_chart.set_index('Local time', inplace=True)

# %% [markdown]
# # DRAW CHART

# %%
def calculate_max_drawdown(values):
    peak = values[0]
    max_drawdown = 0
    
    for value in values:
        # Update the peak value if the current value is greater than the previous peak
        peak = max(peak, value)
        
        # Calculate the drawdown at the current value
        drawdown = (peak - value) 
        
        # Update the max drawdown if the current drawdown is larger
        max_drawdown = max(max_drawdown, drawdown)
    
    return max_drawdown

# %%
# LIQ SEVIYELERİNİ ÇİZEN KOD
def draw_liqs(df, start_time, end_time, low_liqs = [], high_liqs = [], current_idx=None, title="", save_path = None):
    """Creates a candlestick chart with swing liquidity prices and current price."""
    
    df_filtered = df[(df['Local time'] >= start_time) & (df['Local time'] <= end_time)].copy()
    df_filtered['Local time'] = pd.to_datetime(df_filtered['Local time'])
    df_filtered.set_index('Local time', inplace=True)
    
    add_plots = []
    if low_liqs != [] :
        for low in low_liqs:
            add_plots.append(mpf.make_addplot(pd.Series(low, index=df_filtered.index), color='red', linestyle=':'))
    
    if high_liqs != [] :
        for high in high_liqs:
            add_plots.append(mpf.make_addplot(pd.Series(high, index=df_filtered.index), color='green', linestyle=':'))

        # Save each plot as a PNG frame
    if save_path != None:
        mpf.plot(df_filtered, type='candle', volume=False,  style='charles', addplot=add_plots,savefig=save_path)

    if save_path == None:
        mpf.plot(df_filtered, type='candle', volume=False, style='charles', addplot=add_plots)



# POZISYON BİTİNCE SONUCU ÇİZEN KOD
def draw_position(df_chart, start_local_time='2021-09-30 01:00:00', end_local_time='2021-10-03 01:00:00', 
                  current_value=None, high_value=None, low_value=None, trade_hit="STOP", save_path = None):
    """Draws a candlestick chart with entry, take profit, and stop loss prices."""
    start_time = pd.to_datetime(start_local_time)
    end_time = pd.to_datetime(end_local_time)

    df_filtered = df_chart[(df_chart.index >= start_time) & (df_chart.index <= end_time)]
    
    addplot_list = []

    if current_value != None:
        addplot_list.append(mpf.make_addplot([current_value] * len(df_filtered), color='black', linestyle='--', label='Entry Price'))


    if high_value != None:
        addplot_list.append(mpf.make_addplot([high_value] * len(df_filtered), color='green', linestyle='--', label='Take Profit'))


    if low_value != None:
        addplot_list.append(mpf.make_addplot([low_value] * len(df_filtered), color='red', linestyle='--', label='Stop Loss'))

    if save_path != None:
        mpf.plot(df_filtered, type='candle', volume=False, title=trade_hit, style='charles', addplot=addplot_list,savefig=save_path)

    if save_path == None:
        mpf.plot(df_filtered, type='candle', volume=False, title=trade_hit, style='charles', addplot=addplot_list)


def print_iteration(df, current_index, decimal = 10000):
    if current_index % decimal == 0:
        print("Index Left : " ,len(df) - current_index)

# %% [markdown]
# # CONTROL FUNCTIONS

# %%
def check_for_fvg(df, current_index):
    
    """ 
    BULLISH FVG -> 1 
    BEARISH FVG -> - 1 
    NO FVG -> 0 
    
    
    """
    
    # Get the previous candle's high and low
    prev_2_high = df.iloc[current_index - 2]['High']
    prev_2_low = df.iloc[current_index - 2]['Low']
    
    # Get the current candle's high and low
    current_high = df.iloc[current_index]['High']
    current_low = df.iloc[current_index]['Low']

    fvg_body_threshold = 1
    fvg_wick_threshold = 1
    
    current_body = abs(df.iloc[current_index - 1]['Close'] - df.iloc[current_index - 1]['Open'])
    
    # Check for a Bullish FVG (current candle's low is higher than the previous candle's high)
    if current_body > fvg_body_threshold and current_low - prev_2_high > fvg_wick_threshold:
        return 1
    
    # Check for a Bearish FVG (current candle's high is lower than the previous candle's low)
    if current_body > fvg_body_threshold and prev_2_low - current_high > fvg_wick_threshold:
        return - 1
    
    return 0

# %%
def is_bullish(df, current_index):
    return df.iloc[current_index]["Close"] - df.iloc[current_index]["Open"] > 0

# %%
def if_long_cisd(df,current_index = None, cisd_check_range = CISD_CHECK_RANGE):
    """
    BU FONKSİYON ÖN KOŞUL OLARAK SON LIQ SEVİYESİNİN KIRILDIĞINI VARSAYAR
    """
    
    """ LIQ ALINMADAN ÖNCEKİ SON YEŞİL MUMU BULUR """

    bearish_candle_start_idx = current_index
    while is_bullish(df, bearish_candle_start_idx):
        bearish_candle_start_idx -= 1

    bullish_candle_start_idx = bearish_candle_start_idx
    while not is_bullish(df, bullish_candle_start_idx):
        bullish_candle_start_idx -= 1

    cisd_level = df.iloc[bullish_candle_start_idx]["Close"]

    #print("FİRST CISD : ", df.iloc[bullish_candle_start_idx]["Local time"])

    # OB HAS FOUND. CONTINUE WITH CONFIRMATION
    is_confirmed = False
    for confirmation_index in range(current_index + 1, current_index + cisd_check_range):
        if df.iloc[confirmation_index]["Close"] > cisd_level:
            ### OB LEVEL CONFIRMED. OPEN LONG HERE
            is_confirmed = True
            #print("LAST CISD : ", df.iloc[bullish_candle_start_idx]["Local time"])

            break   
            
        bearish_candle_start_idx = confirmation_index
        while is_bullish(df, bearish_candle_start_idx):
            bearish_candle_start_idx -= 1

        bullish_candle_start_idx = bearish_candle_start_idx
        while not is_bullish(df, bullish_candle_start_idx):
            bullish_candle_start_idx -= 1

        cisd_level = df.iloc[bullish_candle_start_idx]["Close"]

    return is_confirmed, cisd_level, confirmation_index

# %%
def if_short_cisd(df,current_index = None, cisd_check_range = CISD_CHECK_RANGE):
    """
    BU FONKSİYON ÖN KOŞUL OLARAK SON LIQ SEVİYESİNİN KIRILDIĞINI VARSAYAR
    """
    
    """ LIQ ALINMADAN ÖNCEKİ SON KIRMIZI MUMU BULUR """

    bullish_candle_start_idx = current_index
    while not is_bullish(df, bullish_candle_start_idx):
        bullish_candle_start_idx -= 1

    bearish_candle_start_idx = bullish_candle_start_idx
    while is_bullish(df, bearish_candle_start_idx):
        bearish_candle_start_idx -= 1

    cisd_level = df.iloc[bearish_candle_start_idx]["Close"]

    #print("FİRST CISD : ", df.iloc[bullish_candle_start_idx]["Local time"])

    # OB HAS FOUND. CONTINUE WITH CONFIRMATION
    is_confirmed = False
    for confirmation_index in range(current_index + 1, current_index + cisd_check_range):
        if df.iloc[confirmation_index]["Close"] < cisd_level:
            ### OB LEVEL CONFIRMED. OPEN LONG HERE
            is_confirmed = True
            #print("LAST CISD : ", df.iloc[bullish_candle_start_idx]["Local time"])

            break   
            
            
        bullish_candle_start_idx = current_index
        while not is_bullish(df, bullish_candle_start_idx):
            bullish_candle_start_idx -= 1

        bearish_candle_start_idx = bullish_candle_start_idx
        while is_bullish(df, bearish_candle_start_idx):
            bearish_candle_start_idx -= 1

        cisd_level = df.iloc[bearish_candle_start_idx]["Close"]


    return is_confirmed, cisd_level, confirmation_index

# %% [markdown]
# # POSITION

# %%
# LONG İŞLEM SONRASI DURUMU KONTROL EDEN KOD
def open_long_position(df, df_chart, entry_index,fvg_index, entry_price, balance, tp_counter, sl_counter, lot_size,total_profit_loss, 
                            visualize = True, position_tp_sl_range = POSITION_TP_SL_RANGE, risk_reward_ration = RISK_REWARD_RATIO,graph_extend = GRAPH_EXTEND, total_rr = None):
    
    stop_price = df.iloc[entry_index - position_tp_sl_range : entry_index + 1]["Low"].min()
    tp_price = entry_price + abs(entry_price - stop_price) * risk_reward_ration


    """  ADJUST tp_price, stop_price LEVELS IN HERE """


    for trade_index in range(entry_index + 1, len(df)):
        if df.iloc[trade_index]["Low"] < stop_price:
            change_rate = 1 - (abs(entry_price - stop_price) / entry_price)
            balance *= change_rate
            sl_counter += 1
            
            total_rr -= 1
        
            total_profit_loss = total_profit_loss - (abs(stop_price - entry_price) * lot_size ) 

            if visualize:
                draw_position(df_chart,df.iloc[fvg_index - graph_extend]["Local time"], df.iloc[trade_index + graph_extend]["Local time"],low_value = stop_price, high_value = tp_price, current_value = entry_price, trade_hit = "LONG SL")
            break

        elif df.iloc[trade_index]["High"] > tp_price:

            change_rate = 1 + (abs(tp_price - entry_price) / entry_price)
            balance *= change_rate
            tp_counter += 1

            total_rr += risk_reward_ration

            total_profit_loss = total_profit_loss + (abs(tp_price - entry_price) * lot_size ) 

            if visualize:
                draw_position(df_chart,df.iloc[fvg_index - graph_extend]["Local time"], df.iloc[trade_index + graph_extend]["Local time"],low_value = stop_price, high_value = tp_price, current_value = entry_price, trade_hit = "LONG TP")

            break
        
        # BURDA FVG'Yİ KIRDIĞI İÇİN İŞLEMİ KAPATIYORUZ
        elif df.iloc[trade_index]["Close"] < df.iloc[fvg_index - 2]["High"]:
            change_rate = 1 - (abs(entry_price - df.iloc[trade_index]["Close"]) / entry_price)
            balance *= change_rate
            sl_counter += 1

            total_rr -= abs(entry_price - df.iloc[trade_index]["Close"]) / (abs(entry_price - stop_price))

            total_profit_loss = total_profit_loss - (abs(stop_price - entry_price) * lot_size ) 


            if visualize:
                draw_position(df_chart,df.iloc[fvg_index - graph_extend]["Local time"], df.iloc[trade_index + graph_extend]["Local time"],low_value = df.iloc[trade_index]["Close"], high_value = tp_price, current_value = entry_price, trade_hit = "LONG SL")
            #print("BREAK THE CYCLE MORTY")
            
            break

    return balance, tp_counter , sl_counter, trade_index, stop_price, tp_price,change_rate, total_profit_loss, total_rr

# %%
# SHORT İŞLEM SONRASI DURUMU KONTROL EDEN KOD
def open_short_position(df, df_chart, entry_index,fvg_index, entry_price, balance, tp_counter, sl_counter, lot_size,total_profit_loss, 
                            visualize = True, position_tp_sl_range = POSITION_TP_SL_RANGE, risk_reward_ration = RISK_REWARD_RATIO,graph_extend = GRAPH_EXTEND, total_rr = None):
    
    stop_price = df.iloc[entry_index - position_tp_sl_range : entry_index + 1]["High"].max()
    tp_price = entry_price - abs(stop_price - entry_price) * risk_reward_ration


    for trade_index in range(entry_index + 1, len(df)):
        if df.iloc[trade_index]["High"] > stop_price:
            change_rate = 1 - (abs(stop_price - entry_price) / entry_price)
            balance *= change_rate
            sl_counter += 1
            total_rr -= 1
            total_profit_loss = total_profit_loss - (abs(stop_price - entry_price) * lot_size ) 

            if visualize:
                draw_position(df_chart,df.iloc[fvg_index - graph_extend]["Local time"], df.iloc[trade_index + graph_extend]["Local time"],low_value = stop_price, high_value = tp_price, current_value = entry_price, trade_hit = "SHORT SL")
            break

        elif df.iloc[trade_index]["Low"] < tp_price:

            change_rate = 1 + (abs(entry_price - tp_price) / entry_price)
            balance *= change_rate
            tp_counter += 1

            total_rr += risk_reward_ration

            total_profit_loss = total_profit_loss + (abs(tp_price - entry_price) * lot_size ) 

            if visualize:
                draw_position(df_chart,df.iloc[fvg_index - graph_extend]["Local time"], df.iloc[trade_index + graph_extend]["Local time"],low_value = stop_price , high_value = tp_price, current_value = entry_price, trade_hit = "SHORT TP")

            break
        

        # BURDA FVG'Yİ KIRDIĞI İÇİN İŞLEMİ KAPATIYORUZ
        elif df.iloc[trade_index]["Close"] > df.iloc[fvg_index - 2]["Low"]:
            change_rate = 1 - (abs(df.iloc[trade_index]["Close"] - entry_price) / entry_price)
            balance *= change_rate
            sl_counter += 1

            total_profit_loss = total_profit_loss - (abs(stop_price - entry_price) * lot_size )
            total_rr -= abs(entry_price - df.iloc[trade_index]["Close"]) / (abs(entry_price - stop_price))

            if visualize:
                draw_position(df_chart,df.iloc[fvg_index - graph_extend]["Local time"], df.iloc[trade_index + graph_extend]["Local time"],low_value = df.iloc[trade_index]["Close"], high_value = tp_price, current_value = entry_price, trade_hit = "SHORT SL")
            #print("BREAK THE CYCLE MORTY")
            
            break
        


    return balance, tp_counter , sl_counter, trade_index, stop_price, tp_price,change_rate, total_profit_loss, total_rr

# %% [markdown]
# # Backtest

# %%
current_index = 100
balance = 100
lot_size = 0.01
total_profit_loss = 0

tp_counter = 0
sl_counter = 0
balances = [balance]
pl_values = []

tp_trades = []
sl_trades = []

low_liqs = []
high_liqs = []

long_trades = 0
short_trades = 0
RR = 1

fr_range = 10
total_rr = 0
total_rr_list = [total_rr]
# Define the start and end time for the check
start_time = datetime.time(00, 00)  # 16:30
end_time = datetime.time(23, 59)  # 23:00

df_for_model = df.copy()
df_for_model["Position Type"] = 0
df_for_model["Is Profitable"] = 0

visualize = False

while current_index < len(df) - 1000:
    current_index += 1
    # BU DATA ÜZERİNDE KAÇ İNDEKSİN KALDIĞINI GÖSTERİYOR
    # print_iteration(df, current_index)

    # Get the current time at the current index
    current_time = df['Local time'].iloc[current_index].time()  # Get time part of the datetime

    # Check if the current time is between start_time and end_time
    if start_time <= current_time <= end_time:

        if check_for_fvg(df, current_index) == 1:
            """ LONG POSITION """
            
            fvg_index = current_index - 1 
            fvg_upper_bound = df.iloc[current_index]["Low"]
            fvg_lower_bound = df.iloc[current_index - 2]["High"]

            fr_check_range = current_index + fr_range

            while current_index < fr_check_range:
                current_index += 1

                if df.iloc[current_index]["Close"] < fvg_lower_bound:
                    break

                if check_for_fvg(df,current_index) == 1:
                    current_index -= 1
                    break


                if df.iloc[current_index]["Low"] <  (fvg_upper_bound + fvg_lower_bound) / 2:
                        long_trades += 1
                        # LİMİT EMRİ BULLİSH FVG HİGH BOUND'A ATIYORUZ
                        entry_price = df.iloc[current_index]["Close"]
                        entry_index = current_index

                        tp_prev = tp_counter

                        balance, tp_counter , sl_counter, trade_index, stop_price, tp_price,change_rate, total_profit_loss, total_rr   = open_long_position(df, df_chart, entry_index,fvg_index, entry_price, balance, 
                                tp_counter, sl_counter, lot_size,total_profit_loss, 
                                visualize = visualize, position_tp_sl_range = POSITION_TP_SL_RANGE, risk_reward_ration = RISK_REWARD_RATIO,graph_extend = GRAPH_EXTEND, total_rr = total_rr )


                        title = F"""
LONG
FVG Time : {df.iloc[fvg_index]['Local time']} , Entry Time : {df.iloc[current_index]['Local time']} , Exit Time : {df.iloc[trade_index]['Local time']} 
Entry Price : {entry_price}, Stop Price : {stop_price}, Take Profit Price : {tp_price}
TOTAL RR : {total_rr} Drawdown : {calculate_max_drawdown(total_rr_list):.2f}
    """
                        print(title)

                        balances.append(balance)
                        total_rr_list.append(total_rr)
                        current_index = trade_index

                        df_for_model.loc[entry_index, "Position Type"] = 1
                        
                        if tp_prev == tp_counter:    
                            df_for_model.loc[entry_index, "Is Profitable"] = -1
                        else:
                            df_for_model.loc[entry_index, "Is Profitable"] = 1


                        break

        elif check_for_fvg(df, current_index) == -1:
            """ SHORT POSITION  """

            fvg_index = current_index - 1

            fvg_lower_bound = df.iloc[current_index]["High"]
            fvg_upper_bound = df.iloc[current_index - 2]["Low"]


            fr_check_range = current_index + fr_range

            while current_index < fr_check_range:
                current_index += 1

                if df.iloc[current_index]["Close"] > fvg_upper_bound:
                    break

                if check_for_fvg(df,current_index) == -1:
                    current_index -= 1
                    break

                if df.iloc[current_index]["High"] > (fvg_upper_bound + fvg_lower_bound) / 2:
                    
                        short_trades += 1
                        # LİMİT EMRİ BULLİSH FVG HİGH BOUND'A ATIYORUZ
                        entry_price = df.iloc[current_index]["Close"]
                        entry_index = current_index

                        tp_prev = tp_counter

                        balance, tp_counter , sl_counter, trade_index, stop_price, tp_price,change_rate, total_profit_loss, total_rr   = open_short_position(df, df_chart, entry_index,fvg_index, entry_price, balance, 
                                tp_counter, sl_counter, lot_size,total_profit_loss, 
                                visualize = visualize, position_tp_sl_range = POSITION_TP_SL_RANGE, risk_reward_ration = RISK_REWARD_RATIO,graph_extend = GRAPH_EXTEND, total_rr = total_rr )


                        title = F"""
SHORT
FVG Time : {df.iloc[fvg_index]['Local time']} , Entry Time : {df.iloc[current_index]['Local time']} , Exit Time : {df.iloc[trade_index]['Local time']} 
Entry Price : {entry_price}, Stop Price : {stop_price}, Take Profit Price : {tp_price}
TOTAL RR : {total_rr} Drawdown : {calculate_max_drawdown(total_rr_list):.2f}
    """
                        print(title)

                        balances.append(balance)
                        total_rr_list.append(total_rr)
                        current_index = trade_index


                        df_for_model.loc[entry_index, "Position Type"] = -1
                        
                        if tp_prev == tp_counter:    
                            df_for_model.loc[entry_index, "Is Profitable"] = -1
                        else:
                            df_for_model.loc[entry_index, "Is Profitable"] = 1

                        break

title = F"TOTAL RR: {total_rr:.2f} TP:{tp_counter} SL:{sl_counter} WIN RATE:{(tp_counter / (tp_counter + sl_counter)):.2f}Drawdown: {calculate_max_drawdown(total_rr_list):.2f}"
plt.figure(figsize=(10, 5))  # Set the figure siz;e
plt.plot(total_rr_list, linestyle='-', color='black', label='Balances')
plt.xlabel("Index", fontsize=12)
plt.ylabel("Value", fontsize=12)
plt.title(title)
plt.grid(True)  # Add a grid for better readability

# Save the plot as an image
plt.savefig(fr"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\Das Reich\AlgoV2\Algorithms\FVG_CISD\FVG\1m_Long_SHORT_CISD.png", dpi=300)  # Save with high resolution
plt.show()  # Display the plot

df.to_csv(r"C:\Users\Nasip-PC\Desktop\Dosyalar\Kodlar\Das Reich\AlgoV2\Algorithms\Data intensive\fvg_mean_threshold_model.csv")
# Out:
# SHORT
# FVG Time : 2021-09-30 01:58:00 , Entry Time : 2021-09-30 02:02:00 , Exit Time : 2021-09-30 02:03:00
# Entry Price : 14800.349, Stop Price : 14806.599, Take Profit Price : 14794.099
# TOTAL RR : -1 Drawdown : 0.00
#
#
# SHORT
# FVG Time : 2021-09-30 02:06:00 , Entry Time : 2021-09-30 02:08:00 , Exit Time : 2021-09-30 02:09:00
# Entry Price : 14803.889, Stop Price : 14808.039, Take Profit Price : 14799.738999999998
# TOTAL RR : -1.149397590361148 Drawdown : 1.00
#
#
# LONG
# FVG Time : 2021-09-30 02:10:00 , Entry Time : 2021-09-30 02:12:00 , Exit Time : 2021-09-30 02:15:00
# Entry Price : 14806.209, Stop Price : 14794.019, Take Profit Price : 14818.399000000001
# TOTAL RR : -1.757272897990315 Drawdown : 1.15
#
#
# SHORT
# FVG Time : 2021-09-30 02:15:00 , Entry Time : 2021-09-30 02:17:00 , Exit Time : 2021-09-30 02:18:00
# Entry Price : 14803.739, Stop Price : 14808.059, Take Profit Price : 14799.419
# TOTAL RR : -2.757272897990315 Drawdown : 1.76
#
#
# LONG
# FVG Time : 2021-09-30 02:19:00 , Entry Time : 2021-09-30 02:23:00 , Exit Time : 2021-09-30 03:12:00
# Entry Price : 14812.319, Stop Price : 14796.289, Take Profit Price : 14828.348999999998
# TOTAL RR : -1.757272897990315 Drawdown : 2.76
#
#
# SHORT
# FVG Time : 2021-09-30 03:24:00 , Entry Time : 2021-09-30 03:27:00 , Exit Time : 2021-09-30 03:29:00
# Entry Price : 14809.629, Stop Price : 14830.349, Take Profit Price : 14788.909000000001
# TOTAL RR : -1.8726203883377808 Drawdown : 2.76
#
#
# SHORT
# FVG Time : 2021-09-30 03:43:00 , Entry Time : 2021-09-30 03:45:00 , Exit Time : 2021-09-30 03:47:00
# Entry Price : 14801.319, Stop Price : 14815.099, Take Profit Price : 14787.538999999999
# TOTAL RR : -2.599761172082335 Drawdown : 2.76
#
#
# LONG
# FVG Time : 2021-09-30 03:55:00 , Entry Time : 2021-09-30 04:01:00 , Exit Time : 2021-09-30 07:02:00
# Entry Price : 14835.319, Stop Price : 14792.829, Take Profit Price : 14877.809
# TOTAL RR : -1.599761172082335 Drawdown : 2.76
#
#
# LONG
# FVG Time : 2021-09-30 07:02:00 , Entry Time : 2021-09-30 07:13:00 , Exit Time : 2021-09-30 07:47:00
# Entry Price : 14872.149, Stop Price : 14851.609, Take Profit Price : 14892.688999999998
# TOTAL RR : -2.2073561087912026 Drawdown : 2.76
#
#
# SHORT
# FVG Time : 2021-09-30 07:54:00 , Entry Time : 2021-09-30 08:00:00 , Exit Time : 2021-09-30 08:01:00
# Entry Price : 14866.029, Stop Price : 14876.789, Take Profit Price : 14855.269
# TOTAL RR : -2.66088770730413 Drawdown : 2.76
#
#
# LONG
# FVG Time : 2021-09-30 08:08:00 , Entry Time : 2021-09-30 08:11:00 , Exit Time : 2021-09-30 08:26:00
# Entry Price : 14873.829, Stop Price : 14857.049, Take Profit Price : 14890.608999999999
# TOTAL RR : -2.9779318074233245 Drawdown : 2.76
#
#
# LONG
# FVG Time : 2021-09-30 08:42:00 , Entry Time : 2021-09-30 08:44:00 , Exit Time : 2021-09-30 08:50:00
# Entry Price : 14870.249, Stop Price : 14859.849, Take Profit Price : 14880.649
# TOTAL RR : -3.3202394997309796 Drawdown : 2.98
#
#
# LONG
# FVG Time : 2021-09-30 09:21:00 , Entry Time : 2021-09-30 09:32:00 , Exit Time : 2021-09-30 10:15:00
# Entry Price : 14865.027, Stop Price : 14829.649, Take Profit Price : 14900.405
# TOTAL RR : -3.578252954420347 Drawdown : 3.32
#
#
# SHORT
# FVG Time : 2021-09-30 10:15:00 , Entry Time : 2021-09-30 10:25:00 , Exit Time : 2021-09-30 10:36:00
# Entry Price : 14859.349, Stop Price : 14879.799, Take Profit Price : 14838.899
# TOTAL RR : -2.578252954420347 Drawdown : 3.58
#
#
# SHORT
# FVG Time : 2021-09-30 10:36:00 , Entry Time : 2021-09-30 10:38:00 , Exit Time : 2021-09-30 10:41:00
# Entry Price : 14847.999, Stop Price : 14860.909, Take Profit Price : 14835.089
# TOTAL RR : -2.6084620946216965 Drawdown : 3.58
#
#
# SHORT
# FVG Time : 2021-09-30 10:57:00 , Entry Time : 2021-09-30 10:59:00 , Exit Time : 2021-09-30 11:00:00
# Entry Price : 14856.139, Stop Price : 14859.889, Take Profit Price : 14852.389
# TOTAL RR : -3.1471287612884797 Drawdown : 3.58
#
#
# SHORT
# FVG Time : 2021-09-30 11:25:00 , Entry Time : 2021-09-30 11:30:00 , Exit Time : 2021-09-30 11:33:00
# Entry Price : 14842.539, Stop Price : 14857.289, Take Profit Price : 14827.789
# TOTAL RR : -3.301027066373132 Drawdown : 3.58
#
#
# SHORT
# FVG Time : 2021-09-30 11:42:00 , Entry Time : 2021-09-30 11:52:00 , Exit Time : 2021-09-30 12:22:00
# Entry Price : 14826.369, Stop Price : 14848.699, Take Profit Price : 14804.039
# TOTAL RR : -2.301027066373132 Drawdown : 3.58
#
#
# SHORT
# FVG Time : 2021-09-30 12:22:00 , Entry Time : 2021-09-30 12:25:00 , Exit Time : 2021-09-30 12:35:00
# Entry Price : 14807.349, Stop Price : 14836.489, Take Profit Price : 14778.209
# TOTAL RR : -2.4506495783841364 Drawdown : 3.58
#
#
# SHORT
# FVG Time : 2021-09-30 12:58:00 , Entry Time : 2021-09-30 13:00:00 , Exit Time : 2021-09-30 13:03:00
# Entry Price : 14815.889, Stop Price : 14824.499, Take Profit Price : 14807.278999999999
# TOTAL RR : -1.4506495783841364 Drawdown : 3.58
#
#
# LONG
# FVG Time : 2021-09-30 13:11:00 , Entry Time : 2021-09-30 13:15:00 , Exit Time : 2021-09-30 13:32:00
# Entry Price : 14825.329, Stop Price : 14798.719, Take Profit Price : 14851.939
# TOTAL RR : -1.813670998902725 Drawdown : 3.58
#
#
# SHORT
# FVG Time : 2021-09-30 13:38:00 , Entry Time : 2021-09-30 13:41:00 , Exit Time : 2021-09-30 13:53:00
# Entry Price : 14813.649, Stop Price : 14831.619, Take Profit Price : 14795.678999999998
# TOTAL RR : -2.1330922565543338 Drawdown : 3.58
#
#
# SHORT
# FVG Time : 2021-09-30 14:13:00 , Entry Time : 2021-09-30 14:15:00 , Exit Time : 2021-09-30 14:30:00
# Entry Price : 14812.179, Stop Price : 14822.819, Take Profit Price : 14801.539
# TOTAL RR : -3.1330922565543338 Drawdown : 3.58
#
#
# LONG
# FVG Time : 2021-09-30 14:30:00 , Entry Time : 2021-09-30 14:37:00 , Exit Time : 2021-09-30 14:38:00
# Entry Price : 14821.289, Stop Price : 14807.329, Take Profit Price : 14835.249000000002
# TOTAL RR : -3.682519190651723 Drawdown : 3.58
#
#
# LONG
# FVG Time : 2021-09-30 14:41:00 , Entry Time : 2021-09-30 14:45:00 , Exit Time : 2021-09-30 14:58:00
# Entry Price : 14829.209, Stop Price : 14807.819, Take Profit Price : 14850.599000000002
# TOTAL RR : -4.248204090137448 Drawdown : 3.68
#
#
# SHORT
# FVG Time : 2021-09-30 15:05:00 , Entry Time : 2021-09-30 15:10:00 , Exit Time : 2021-09-30 15:15:00
# Entry Price : 14798.029, Stop Price : 14829.599, Take Profit Price : 14766.459
# TOTAL RR : -4.564643748040517 Drawdown : 4.25
#
#
# SHORT
# FVG Time : 2021-09-30 15:17:00 , Entry Time : 2021-09-30 15:23:00 , Exit Time : 2021-09-30 15:24:00
# Entry Price : 14805.589, Stop Price : 14814.169, Take Profit Price : 14797.009
# TOTAL RR : -5.441100624497452 Drawdown : 4.56
#
#
# LONG
# FVG Time : 2021-09-30 15:35:00 , Entry Time : 2021-09-30 15:37:00 , Exit Time : 2021-09-30 15:38:00
# Entry Price : 14874.519, Stop Price : 14791.529, Take Profit Price : 14957.509
# TOTAL RR : -5.770537906097647 Drawdown : 5.44
#
#
# SHORT
# FVG Time : 2021-09-30 15:38:00 , Entry Time : 2021-09-30 15:47:00 , Exit Time : 2021-09-30 15:49:00
# Entry Price : 14859.899, Stop Price : 14882.819, Take Profit Price : 14836.979
# TOTAL RR : -6.475162687947621 Drawdown : 5.77
#
#
# LONG
# FVG Time : 2021-09-30 16:09:00 , Entry Time : 2021-09-30 16:12:00 , Exit Time : 2021-09-30 16:13:00
# Entry Price : 14837.609, Stop Price : 14816.059, Take Profit Price : 14859.159000000001
# TOTAL RR : -6.907181249432494 Drawdown : 6.48
#
#
# SHORT
# FVG Time : 2021-09-30 16:30:00 , Entry Time : 2021-09-30 16:35:00 , Exit Time : 2021-09-30 17:16:00
# Entry Price : 14829.789, Stop Price : 14878.999, Take Profit Price : 14780.579000000002
# TOTAL RR : -7.171355197816974 Drawdown : 6.91
#
#
# SHORT
# FVG Time : 2021-09-30 17:24:00 , Entry Time : 2021-09-30 17:26:00 , Exit Time : 2021-09-30 17:29:00
# Entry Price : 14833.619, Stop Price : 14852.367, Take Profit Price : 14814.871000000001
# TOTAL RR : -7.623670111407743 Drawdown : 7.17
#
#
# LONG
# FVG Time : 2021-09-30 17:29:00 , Entry Time : 2021-09-30 17:31:00 , Exit Time : 2021-09-30 17:32:00
# Entry Price : 14836.229, Stop Price : 14810.629, Take Profit Price : 14861.828999999998
# TOTAL RR : -8.100232611407728 Drawdown : 7.62
#
#
# SHORT
# FVG Time : 2021-09-30 17:40:00 , Entry Time : 2021-09-30 17:45:00 , Exit Time : 2021-09-30 19:10:00
# Entry Price : 14768.799, Stop Price : 14844.227, Take Profit Price : 14693.371000000001
# TOTAL RR : -8.166123262094468 Drawdown : 8.10
#
#
# SHORT
# FVG Time : 2021-09-30 19:17:00 , Entry Time : 2021-09-30 19:19:00 , Exit Time : 2021-09-30 19:21:00
# Entry Price : 14770.819, Stop Price : 14783.769, Take Profit Price : 14757.868999999999
# TOTAL RR : -8.375389671360798 Drawdown : 8.17
#
#
# LONG
# FVG Time : 2021-09-30 19:37:00 , Entry Time : 2021-09-30 19:42:00 , Exit Time : 2021-09-30 19:54:00
# Entry Price : 14751.799, Stop Price : 14731.117, Take Profit Price : 14772.481000000002
# TOTAL RR : -7.375389671360798 Drawdown : 8.38
#
#
# LONG
# FVG Time : 2021-09-30 19:54:00 , Entry Time : 2021-09-30 19:56:00 , Exit Time : 2021-09-30 20:00:00
# Entry Price : 14766.539, Stop Price : 14735.519, Take Profit Price : 14797.559000000001
# TOTAL RR : -6.375389671360798 Drawdown : 8.38
#
#
# LONG
# FVG Time : 2021-09-30 20:41:00 , Entry Time : 2021-09-30 20:43:00 , Exit Time : 2021-09-30 20:54:00
# Entry Price : 14820.789, Stop Price : 14793.119, Take Profit Price : 14848.459
# TOTAL RR : -6.941706982528129 Drawdown : 8.38
#
#
# LONG
# FVG Time : 2021-09-30 21:10:00 , Entry Time : 2021-09-30 21:13:00 , Exit Time : 2021-09-30 21:23:00
# Entry Price : 14808.799, Stop Price : 14771.009, Take Profit Price : 14846.589000000002
# TOTAL RR : -7.092275916108451 Drawdown : 8.38
#
#
# LONG
# FVG Time : 2021-09-30 21:31:00 , Entry Time : 2021-09-30 21:33:00 , Exit Time : 2021-09-30 21:37:00
# Entry Price : 14808.717, Stop Price : 14783.119, Take Profit Price : 14834.315
# TOTAL RR : -7.507073947204646 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-09-30 21:54:00 , Entry Time : 2021-09-30 21:58:00 , Exit Time : 2021-10-01 01:10:00
# Entry Price : 14722.649, Stop Price : 14799.109, Take Profit Price : 14646.188999999998
# TOTAL RR : -7.541340230228459 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-10-01 01:33:00 , Entry Time : 2021-10-01 01:36:00 , Exit Time : 2021-10-01 01:47:00
# Entry Price : 14728.669, Stop Price : 14735.989, Take Profit Price : 14721.349
# TOTAL RR : -6.541340230228459 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-10-01 01:47:00 , Entry Time : 2021-10-01 01:50:00 , Exit Time : 2021-10-01 01:59:00
# Entry Price : 14720.279, Stop Price : 14735.989, Take Profit Price : 14704.569000000001
# TOTAL RR : -6.969093253780319 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-10-01 02:19:00 , Entry Time : 2021-10-01 02:22:00 , Exit Time : 2021-10-01 02:23:00
# Entry Price : 14735.599, Stop Price : 14742.829, Take Profit Price : 14728.369
# TOTAL RR : -7.189010266228486 Drawdown : 8.38
#
#
# LONG
# FVG Time : 2021-10-01 02:39:00 , Entry Time : 2021-10-01 02:42:00 , Exit Time : 2021-10-01 02:43:00
# Entry Price : 14736.729, Stop Price : 14727.279, Take Profit Price : 14746.178999999998
# TOTAL RR : -7.231338308556495 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-10-01 02:52:00 , Entry Time : 2021-10-01 02:54:00 , Exit Time : 2021-10-01 03:01:00
# Entry Price : 14715.809, Stop Price : 14739.719, Take Profit Price : 14691.899
# TOTAL RR : -6.231338308556495 Drawdown : 8.38
#
#
# LONG
# FVG Time : 2021-10-01 03:22:00 , Entry Time : 2021-10-01 03:24:00 , Exit Time : 2021-10-01 03:32:00
# Entry Price : 14627.879, Stop Price : 14585.579, Take Profit Price : 14670.179000000002
# TOTAL RR : -6.424009703355579 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-10-01 03:35:00 , Entry Time : 2021-10-01 03:39:00 , Exit Time : 2021-10-01 03:44:00
# Entry Price : 14609.389, Stop Price : 14636.399, Take Profit Price : 14582.378999999999
# TOTAL RR : -7.108570976958002 Drawdown : 8.38
#
#
# LONG
# FVG Time : 2021-10-01 03:44:00 , Entry Time : 2021-10-01 03:47:00 , Exit Time : 2021-10-01 03:58:00
# Entry Price : 14623.599, Stop Price : 14595.039, Take Profit Price : 14652.159
# TOTAL RR : -7.627478539983211 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-10-01 03:58:00 , Entry Time : 2021-10-01 04:01:00 , Exit Time : 2021-10-01 04:23:00
# Entry Price : 14619.709, Stop Price : 14632.229, Take Profit Price : 14607.189000000002
# TOTAL RR : -8.061184610270677 Drawdown : 8.38
#
#
# LONG
# FVG Time : 2021-10-01 04:25:00 , Entry Time : 2021-10-01 04:27:00 , Exit Time : 2021-10-01 04:28:00
# Entry Price : 14627.767, Stop Price : 14612.069, Take Profit Price : 14643.465
# TOTAL RR : -8.214579947256242 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-10-01 04:31:00 , Entry Time : 2021-10-01 04:34:00 , Exit Time : 2021-10-01 04:36:00
# Entry Price : 14623.079, Stop Price : 14630.409, Take Profit Price : 14615.749
# TOTAL RR : -8.43149672761097 Drawdown : 8.38
#
#
# SHORT
# FVG Time : 2021-10-01 04:45:00 , Entry Time : 2021-10-01 04:48:00 , Exit Time : 2021-10-01 04:49:00
# Entry Price : 14617.649, Stop Price : 14629.749, Take Profit Price : 14605.548999999999
# TOTAL RR : -7.43149672761097 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 05:01:00 , Entry Time : 2021-10-01 05:03:00 , Exit Time : 2021-10-01 05:51:00
# Entry Price : 14620.669, Stop Price : 14598.859, Take Profit Price : 14642.479
# TOTAL RR : -8.046810803722863 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 06:00:00 , Entry Time : 2021-10-01 06:02:00 , Exit Time : 2021-10-01 06:03:00
# Entry Price : 14614.549, Stop Price : 14607.119, Take Profit Price : 14621.979000000001
# TOTAL RR : -8.21504768124641 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 06:20:00 , Entry Time : 2021-10-01 06:25:00 , Exit Time : 2021-10-01 06:27:00
# Entry Price : 14613.119, Stop Price : 14617.099, Take Profit Price : 14609.139000000001
# TOTAL RR : -7.215047681246411 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 06:29:00 , Entry Time : 2021-10-01 06:32:00 , Exit Time : 2021-10-01 06:39:00
# Entry Price : 14604.239, Stop Price : 14617.099, Take Profit Price : 14591.378999999999
# TOTAL RR : -7.413336950297809 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 07:05:00 , Entry Time : 2021-10-01 07:07:00 , Exit Time : 2021-10-01 07:08:00
# Entry Price : 14606.619, Stop Price : 14620.389, Take Profit Price : 14592.849000000002
# TOTAL RR : -7.550591852258564 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 07:16:00 , Entry Time : 2021-10-01 07:21:00 , Exit Time : 2021-10-01 08:00:00
# Entry Price : 14615.719, Stop Price : 14597.839, Take Profit Price : 14633.598999999998
# TOTAL RR : -6.550591852258564 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 08:00:00 , Entry Time : 2021-10-01 08:10:00 , Exit Time : 2021-10-01 08:14:00
# Entry Price : 14634.109, Stop Price : 14613.219, Take Profit Price : 14654.999000000002
# TOTAL RR : -7.550591852258564 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 08:20:00 , Entry Time : 2021-10-01 08:28:00 , Exit Time : 2021-10-01 09:18:00
# Entry Price : 14587.569, Stop Price : 14648.399, Take Profit Price : 14526.739
# TOTAL RR : -7.8723081106836785 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 09:27:00 , Entry Time : 2021-10-01 09:30:00 , Exit Time : 2021-10-01 09:38:00
# Entry Price : 14640.149, Stop Price : 14572.299, Take Profit Price : 14707.998999999998
# TOTAL RR : -8.10517472822236 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 09:38:00 , Entry Time : 2021-10-01 09:40:00 , Exit Time : 2021-10-01 09:45:00
# Entry Price : 14628.809, Stop Price : 14645.589, Take Profit Price : 14612.028999999999
# TOTAL RR : -7.1051747282223605 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 09:50:00 , Entry Time : 2021-10-01 09:52:00 , Exit Time : 2021-10-01 09:56:00
# Entry Price : 14622.199, Stop Price : 14603.139, Take Profit Price : 14641.259000000002
# TOTAL RR : -6.1051747282223605 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 09:58:00 , Entry Time : 2021-10-01 10:00:00 , Exit Time : 2021-10-01 10:01:00
# Entry Price : 14637.799, Stop Price : 14655.759, Take Profit Price : 14619.839000000002
# TOTAL RR : -6.467646888578637 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 10:43:00 , Entry Time : 2021-10-01 10:45:00 , Exit Time : 2021-10-01 10:46:00
# Entry Price : 14614.009, Stop Price : 14600.759, Take Profit Price : 14627.259
# TOTAL RR : -6.817080850842727 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 10:46:00 , Entry Time : 2021-10-01 10:49:00 , Exit Time : 2021-10-01 11:03:00
# Entry Price : 14610.529, Stop Price : 14631.669, Take Profit Price : 14589.389000000001
# TOTAL RR : -7.070155590672457 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 11:14:00 , Entry Time : 2021-10-01 11:16:00 , Exit Time : 2021-10-01 11:17:00
# Entry Price : 14622.219, Stop Price : 14590.849, Take Profit Price : 14653.588999999998
# TOTAL RR : -7.081950298992535 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 11:30:00 , Entry Time : 2021-10-01 11:32:00 , Exit Time : 2021-10-01 11:33:00
# Entry Price : 14627.369, Stop Price : 14614.019, Take Profit Price : 14640.719000000001
# TOTAL RR : -7.385321085509462 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 11:49:00 , Entry Time : 2021-10-01 11:51:00 , Exit Time : 2021-10-01 11:54:00
# Entry Price : 14622.639, Stop Price : 14614.609, Take Profit Price : 14630.668999999998
# TOTAL RR : -7.6343870880001585 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 12:00:00 , Entry Time : 2021-10-01 12:02:00 , Exit Time : 2021-10-01 12:13:00
# Entry Price : 14630.599, Stop Price : 14617.049, Take Profit Price : 14644.149
# TOTAL RR : -6.6343870880001585 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 12:13:00 , Entry Time : 2021-10-01 12:15:00 , Exit Time : 2021-10-01 12:22:00
# Entry Price : 14642.369, Stop Price : 14619.809, Take Profit Price : 14664.929000000002
# TOTAL RR : -7.010273612822893 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 12:22:00 , Entry Time : 2021-10-01 12:25:00 , Exit Time : 2021-10-01 12:55:00
# Entry Price : 14633.309, Stop Price : 14648.789, Take Profit Price : 14617.828999999998
# TOTAL RR : -7.906914439696264 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 13:25:00 , Entry Time : 2021-10-01 13:27:00 , Exit Time : 2021-10-01 14:37:00
# Entry Price : 14721.209, Stop Price : 14675.319, Take Profit Price : 14767.099000000002
# TOTAL RR : -8.208069375412132 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 14:44:00 , Entry Time : 2021-10-01 14:46:00 , Exit Time : 2021-10-01 14:51:00
# Entry Price : 14697.779, Stop Price : 14748.899, Take Profit Price : 14646.659000000001
# TOTAL RR : -8.395275948182082 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 14:51:00 , Entry Time : 2021-10-01 14:53:00 , Exit Time : 2021-10-01 15:00:00
# Entry Price : 14704.719, Stop Price : 14690.879, Take Profit Price : 14718.558999999997
# TOTAL RR : -7.395275948182082 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 15:08:00 , Entry Time : 2021-10-01 15:10:00 , Exit Time : 2021-10-01 15:12:00
# Entry Price : 14725.139, Stop Price : 14735.489, Take Profit Price : 14714.788999999999
# TOTAL RR : -7.541169667988862 Drawdown : 8.43
#
#
# LONG
# FVG Time : 2021-10-01 15:35:00 , Entry Time : 2021-10-01 15:37:00 , Exit Time : 2021-10-01 15:38:00
# Entry Price : 14701.299, Stop Price : 14681.119, Take Profit Price : 14721.479000000001
# TOTAL RR : -8.462378785927408 Drawdown : 8.43
#
#
# SHORT
# FVG Time : 2021-10-01 15:44:00 , Entry Time : 2021-10-01 15:48:00 , Exit Time : 2021-10-01 15:49:00
# Entry Price : 14659.789, Stop Price : 14747.079, Take Profit Price : 14572.499000000002
# TOTAL RR : -8.484603553942078 Drawdown : 8.46
#
#
# LONG
# FVG Time : 2021-10-01 16:57:00 , Entry Time : 2021-10-01 17:07:00 , Exit Time : 2021-10-01 17:08:00
# Entry Price : 14620.559, Stop Price : 14563.759, Take Profit Price : 14677.358999999999
# TOTAL RR : -8.721223272251917 Drawdown : 8.48
#
#
# SHORT
# FVG Time : 2021-10-01 17:08:00 , Entry Time : 2021-10-01 17:12:00 , Exit Time : 2021-10-01 17:13:00
# Entry Price : 14613.069, Stop Price : 14644.369, Take Profit Price : 14581.768999999998
# TOTAL RR : -9.721223272251917 Drawdown : 8.72
#
#
# LONG
# FVG Time : 2021-10-01 17:14:00 , Entry Time : 2021-10-01 17:17:00 , Exit Time : 2021-10-01 19:47:00
# Entry Price : 14666.519, Stop Price : 14596.199, Take Profit Price : 14736.839
# TOTAL RR : -8.721223272251917 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-01 19:48:00 , Entry Time : 2021-10-01 19:50:00 , Exit Time : 2021-10-01 19:58:00
# Entry Price : 14745.039, Stop Price : 14703.209, Take Profit Price : 14786.869
# TOTAL RR : -9.090575411864654 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-01 20:21:00 , Entry Time : 2021-10-01 20:24:00 , Exit Time : 2021-10-01 20:49:00
# Entry Price : 14755.089, Stop Price : 14731.629, Take Profit Price : 14778.548999999999
# TOTAL RR : -8.090575411864654 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-01 21:12:00 , Entry Time : 2021-10-01 21:17:00 , Exit Time : 2021-10-01 21:18:00
# Entry Price : 14815.409, Stop Price : 14789.739, Take Profit Price : 14841.079
# TOTAL RR : -8.332102486270532 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-01 21:30:00 , Entry Time : 2021-10-01 21:32:00 , Exit Time : 2021-10-01 21:33:00
# Entry Price : 14787.769, Stop Price : 14830.289, Take Profit Price : 14745.249
# TOTAL RR : -8.594332025310973 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-01 21:33:00 , Entry Time : 2021-10-01 21:36:00 , Exit Time : 2021-10-01 21:37:00
# Entry Price : 14793.249, Stop Price : 14784.339, Take Profit Price : 14802.159
# TOTAL RR : -7.5943320253109725 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-01 21:46:00 , Entry Time : 2021-10-01 21:50:00 , Exit Time : 2021-10-01 21:51:00
# Entry Price : 14791.739, Stop Price : 14806.999, Take Profit Price : 14776.479
# TOTAL RR : -8.203768460435544 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-01 21:58:00 , Entry Time : 2021-10-01 22:01:00 , Exit Time : 2021-10-01 22:02:00
# Entry Price : 14794.599, Stop Price : 14825.559, Take Profit Price : 14763.639000000001
# TOTAL RR : -8.22896225888518 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-01 22:06:00 , Entry Time : 2021-10-01 22:08:00 , Exit Time : 2021-10-01 22:11:00
# Entry Price : 14786.899, Stop Price : 14825.559, Take Profit Price : 14748.239
# TOTAL RR : -8.324927080406155 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 00:41:00 , Entry Time : 2021-10-04 00:44:00 , Exit Time : 2021-10-04 00:53:00
# Entry Price : 14827.659, Stop Price : 14841.539, Take Profit Price : 14813.778999999999
# TOTAL RR : -8.69956684985863 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 00:57:00 , Entry Time : 2021-10-04 00:59:00 , Exit Time : 2021-10-04 01:07:00
# Entry Price : 14830.669, Stop Price : 14836.889, Take Profit Price : 14824.449
# TOTAL RR : -9.120788714810573 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 01:27:00 , Entry Time : 2021-10-04 01:33:00 , Exit Time : 2021-10-04 01:34:00
# Entry Price : 14835.569, Stop Price : 14829.749, Take Profit Price : 14841.389
# TOTAL RR : -9.36477496910613 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 02:00:00 , Entry Time : 2021-10-04 02:04:00 , Exit Time : 2021-10-04 02:05:00
# Entry Price : 14824.059, Stop Price : 14838.307, Take Profit Price : 14809.810999999998
# TOTAL RR : -9.485493666467232 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 02:18:00 , Entry Time : 2021-10-04 02:23:00 , Exit Time : 2021-10-04 02:41:00
# Entry Price : 14806.819, Stop Price : 14828.059, Take Profit Price : 14785.579
# TOTAL RR : -8.485493666467232 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 02:52:00 , Entry Time : 2021-10-04 02:55:00 , Exit Time : 2021-10-04 03:20:00
# Entry Price : 14771.199, Stop Price : 14806.609, Take Profit Price : 14735.789
# TOTAL RR : -8.914750938424277 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 03:20:00 , Entry Time : 2021-10-04 03:25:00 , Exit Time : 2021-10-04 03:26:00
# Entry Price : 14780.599, Stop Price : 14749.359, Take Profit Price : 14811.839
# TOTAL RR : -9.045032628565114 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 03:39:00 , Entry Time : 2021-10-04 03:45:00 , Exit Time : 2021-10-04 04:41:00
# Entry Price : 14746.289, Stop Price : 14785.099, Take Profit Price : 14707.479000000001
# TOTAL RR : -9.30553249973231 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 05:02:00 , Entry Time : 2021-10-04 05:06:00 , Exit Time : 2021-10-04 05:13:00
# Entry Price : 14740.169, Stop Price : 14758.799, Take Profit Price : 14721.538999999999
# TOTAL RR : -8.30553249973231 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 05:15:00 , Entry Time : 2021-10-04 05:18:00 , Exit Time : 2021-10-04 05:26:00
# Entry Price : 14730.489, Stop Price : 14720.099, Take Profit Price : 14740.878999999999
# TOTAL RR : -7.30553249973231 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 05:56:00 , Entry Time : 2021-10-04 06:03:00 , Exit Time : 2021-10-04 06:31:00
# Entry Price : 14716.809, Stop Price : 14736.389, Take Profit Price : 14697.229
# TOTAL RR : -7.548637709129666 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 06:49:00 , Entry Time : 2021-10-04 06:52:00 , Exit Time : 2021-10-04 06:53:00
# Entry Price : 14743.819, Stop Price : 14750.869, Take Profit Price : 14736.768999999998
# TOTAL RR : -7.605375297782088 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 07:09:00 , Entry Time : 2021-10-04 07:12:00 , Exit Time : 2021-10-04 07:15:00
# Entry Price : 14741.209, Stop Price : 14735.569, Take Profit Price : 14746.849000000002
# TOTAL RR : -6.605375297782088 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 07:40:00 , Entry Time : 2021-10-04 07:42:00 , Exit Time : 2021-10-04 07:50:00
# Entry Price : 14713.519, Stop Price : 14746.409, Take Profit Price : 14680.629
# TOTAL RR : -6.988470463485967 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 07:50:00 , Entry Time : 2021-10-04 07:53:00 , Exit Time : 2021-10-04 07:57:00
# Entry Price : 14728.189, Stop Price : 14705.029, Take Profit Price : 14751.349
# TOTAL RR : -7.713427285593091 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 08:18:00 , Entry Time : 2021-10-04 08:21:00 , Exit Time : 2021-10-04 08:23:00
# Entry Price : 14675.189, Stop Price : 14716.319, Take Profit Price : 14634.059000000001
# TOTAL RR : -7.774453300667252 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 08:31:00 , Entry Time : 2021-10-04 08:33:00 , Exit Time : 2021-10-04 08:46:00
# Entry Price : 14698.139, Stop Price : 14662.019, Take Profit Price : 14734.258999999998
# TOTAL RR : -7.996767807865455 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 09:00:00 , Entry Time : 2021-10-04 09:05:00 , Exit Time : 2021-10-04 09:09:00
# Entry Price : 14677.899, Stop Price : 14699.099, Take Profit Price : 14656.698999999999
# TOTAL RR : -8.45620177012958 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 09:10:00 , Entry Time : 2021-10-04 09:13:00 , Exit Time : 2021-10-04 09:19:00
# Entry Price : 14693.329, Stop Price : 14662.849, Take Profit Price : 14723.809
# TOTAL RR : -8.963747701888096 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 09:38:00 , Entry Time : 2021-10-04 09:40:00 , Exit Time : 2021-10-04 09:48:00
# Entry Price : 14659.659, Stop Price : 14643.339, Take Profit Price : 14675.979
# TOTAL RR : -7.963747701888096 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 10:08:00 , Entry Time : 2021-10-04 10:10:00 , Exit Time : 2021-10-04 10:11:00
# Entry Price : 14703.309, Stop Price : 14714.599, Take Profit Price : 14692.018999999998
# TOTAL RR : -8.963747701888096 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 10:34:00 , Entry Time : 2021-10-04 10:37:00 , Exit Time : 2021-10-04 10:53:00
# Entry Price : 14682.529, Stop Price : 14709.579, Take Profit Price : 14655.479000000001
# TOTAL RR : -9.203304078967568 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 11:00:00 , Entry Time : 2021-10-04 11:04:00 , Exit Time : 2021-10-04 11:36:00
# Entry Price : 14710.279, Stop Price : 14673.129, Take Profit Price : 14747.429
# TOTAL RR : -9.45606316375899 Drawdown : 9.72
#
#
# SHORT
# FVG Time : 2021-10-04 11:54:00 , Entry Time : 2021-10-04 11:59:00 , Exit Time : 2021-10-04 12:00:00
# Entry Price : 14707.719, Stop Price : 14727.489, Take Profit Price : 14687.948999999999
# TOTAL RR : -9.803053553238021 Drawdown : 9.72
#
#
# LONG
# FVG Time : 2021-10-04 12:07:00 , Entry Time : 2021-10-04 12:16:00 , Exit Time : 2021-10-04 12:17:00
# Entry Price : 14717.129, Stop Price : 14697.239, Take Profit Price : 14737.019000000002
# TOTAL RR : -9.971479898134962 Drawdown : 9.80
#
#
# LONG
# FVG Time : 2021-10-04 12:27:00 , Entry Time : 2021-10-04 12:37:00 , Exit Time : 2021-10-04 12:40:00
# Entry Price : 14701.329, Stop Price : 14693.899, Take Profit Price : 14708.759
# TOTAL RR : -10.858424716439119 Drawdown : 9.97
#
#
# SHORT
# FVG Time : 2021-10-04 12:40:00 , Entry Time : 2021-10-04 12:43:00 , Exit Time : 2021-10-04 12:45:00
# Entry Price : 14700.099, Stop Price : 14712.599, Take Profit Price : 14687.599
# TOTAL RR : -9.858424716439119 Drawdown : 10.86
#
#
# LONG
# FVG Time : 2021-10-04 12:55:00 , Entry Time : 2021-10-04 12:57:00 , Exit Time : 2021-10-04 13:04:00
# Entry Price : 14710.189, Stop Price : 14687.209, Take Profit Price : 14733.169
# TOTAL RR : -10.287058310869082 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 13:04:00 , Entry Time : 2021-10-04 13:07:00 , Exit Time : 2021-10-04 13:13:00
# Entry Price : 14703.389, Stop Price : 14718.099, Take Profit Price : 14688.678999999998
# TOTAL RR : -9.287058310869082 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 13:13:00 , Entry Time : 2021-10-04 13:16:00 , Exit Time : 2021-10-04 14:00:00
# Entry Price : 14681.339, Stop Price : 14718.099, Take Profit Price : 14644.579
# TOTAL RR : -9.767743838616632 Drawdown : 10.86
#
#
# LONG
# FVG Time : 2021-10-04 14:46:00 , Entry Time : 2021-10-04 14:55:00 , Exit Time : 2021-10-04 15:00:00
# Entry Price : 14735.149, Stop Price : 14703.739, Take Profit Price : 14766.559
# TOTAL RR : -9.925973701717535 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 15:03:00 , Entry Time : 2021-10-04 15:07:00 , Exit Time : 2021-10-04 15:30:00
# Entry Price : 14725.179, Stop Price : 14745.489, Take Profit Price : 14704.869
# TOTAL RR : -8.925973701717535 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 16:02:00 , Entry Time : 2021-10-04 16:04:00 , Exit Time : 2021-10-04 16:30:00
# Entry Price : 14566.029, Stop Price : 14620.799, Take Profit Price : 14511.259
# TOTAL RR : -7.925973701717535 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 16:35:00 , Entry Time : 2021-10-04 16:40:00 , Exit Time : 2021-10-04 16:44:00
# Entry Price : 14466.759, Stop Price : 14547.499, Take Profit Price : 14386.019
# TOTAL RR : -8.136278383411858 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 16:53:00 , Entry Time : 2021-10-04 16:55:00 , Exit Time : 2021-10-04 16:59:00
# Entry Price : 14422.139, Stop Price : 14485.609, Take Profit Price : 14358.668999999998
# TOTAL RR : -8.633993839532852 Drawdown : 10.86
#
#
# LONG
# FVG Time : 2021-10-04 16:59:00 , Entry Time : 2021-10-04 17:01:00 , Exit Time : 2021-10-04 17:02:00
# Entry Price : 14443.529, Stop Price : 14417.789, Take Profit Price : 14469.269
# TOTAL RR : -9.053962759501827 Drawdown : 10.86
#
#
# LONG
# FVG Time : 2021-10-04 17:08:00 , Entry Time : 2021-10-04 17:11:00 , Exit Time : 2021-10-04 17:24:00
# Entry Price : 14474.809, Stop Price : 14417.789, Take Profit Price : 14531.828999999998
# TOTAL RR : -9.599210041157402 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 17:37:00 , Entry Time : 2021-10-04 17:41:00 , Exit Time : 2021-10-04 17:53:00
# Entry Price : 14405.349, Stop Price : 14482.119, Take Profit Price : 14328.579
# TOTAL RR : -9.940619445872773 Drawdown : 10.86
#
#
# LONG
# FVG Time : 2021-10-04 17:58:00 , Entry Time : 2021-10-04 18:00:00 , Exit Time : 2021-10-04 18:02:00
# Entry Price : 14458.239, Stop Price : 14396.529, Take Profit Price : 14519.948999999999
# TOTAL RR : -10.198146588961414 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 18:02:00 , Entry Time : 2021-10-04 18:06:00 , Exit Time : 2021-10-04 18:07:00
# Entry Price : 14445.089, Stop Price : 14465.809, Take Profit Price : 14424.369
# TOTAL RR : -10.60934350015836 Drawdown : 10.86
#
#
# SHORT
# FVG Time : 2021-10-04 18:40:00 , Entry Time : 2021-10-04 18:42:00 , Exit Time : 2021-10-04 18:49:00
# Entry Price : 14390.289, Stop Price : 14435.089, Take Profit Price : 14345.489000000001
# TOTAL RR : -10.96202207158692 Drawdown : 10.86
#
#
# LONG
# FVG Time : 2021-10-04 19:12:00 , Entry Time : 2021-10-04 19:15:00 , Exit Time : 2021-10-04 19:16:00
# Entry Price : 14435.299, Stop Price : 14380.819, Take Profit Price : 14489.779000000002
# TOTAL RR : -11.09766818025067 Drawdown : 10.96
#
#
# SHORT
# FVG Time : 2021-10-04 19:20:00 , Entry Time : 2021-10-04 19:22:00 , Exit Time : 2021-10-04 19:24:00
# Entry Price : 14424.299, Stop Price : 14449.399, Take Profit Price : 14399.199000000002
# TOTAL RR : -11.236233917302437 Drawdown : 11.10
#
#
# SHORT
# FVG Time : 2021-10-04 19:52:00 , Entry Time : 2021-10-04 20:00:00 , Exit Time : 2021-10-04 20:01:00
# Entry Price : 14426.669, Stop Price : 14447.889, Take Profit Price : 14405.449
# TOTAL RR : -11.95112552898955 Drawdown : 11.24
#
#
# LONG
# FVG Time : 2021-10-04 20:06:00 , Entry Time : 2021-10-04 20:10:00 , Exit Time : 2021-10-04 20:11:00
# Entry Price : 14456.699, Stop Price : 14412.079, Take Profit Price : 14501.319000000001
# TOTAL RR : -12.291107599809806 Drawdown : 11.95
#
#
# LONG
# FVG Time : 2021-10-04 20:38:00 , Entry Time : 2021-10-04 20:40:00 , Exit Time : 2021-10-04 20:44:00
# Entry Price : 14439.859, Stop Price : 14422.639, Take Profit Price : 14457.079000000002
# TOTAL RR : -11.291107599809806 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-04 21:07:00 , Entry Time : 2021-10-04 21:09:00 , Exit Time : 2021-10-04 21:11:00
# Entry Price : 14487.359, Stop Price : 14508.759, Take Profit Price : 14465.959
# TOTAL RR : -10.291107599809806 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-04 21:38:00 , Entry Time : 2021-10-04 21:40:00 , Exit Time : 2021-10-04 21:41:00
# Entry Price : 14416.539, Stop Price : 14444.399, Take Profit Price : 14388.679000000002
# TOTAL RR : -10.667992021920375 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-04 21:46:00 , Entry Time : 2021-10-04 21:48:00 , Exit Time : 2021-10-04 21:49:00
# Entry Price : 14458.629, Stop Price : 14470.649, Take Profit Price : 14446.609000000002
# TOTAL RR : -9.667992021920375 Drawdown : 12.29
#
#
# LONG
# FVG Time : 2021-10-04 22:07:00 , Entry Time : 2021-10-04 22:10:00 , Exit Time : 2021-10-05 00:02:00
# Entry Price : 14499.319, Stop Price : 14414.019, Take Profit Price : 14584.618999999999
# TOTAL RR : -9.711720040677697 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 00:02:00 , Entry Time : 2021-10-05 00:08:00 , Exit Time : 2021-10-05 00:10:00
# Entry Price : 14500.239, Stop Price : 14510.079, Take Profit Price : 14490.399
# TOTAL RR : -9.950541178889113 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 00:53:00 , Entry Time : 2021-10-05 00:57:00 , Exit Time : 2021-10-05 01:00:00
# Entry Price : 14515.139, Stop Price : 14521.109, Take Profit Price : 14509.168999999998
# TOTAL RR : -10.449703657951224 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 01:05:00 , Entry Time : 2021-10-05 01:12:00 , Exit Time : 2021-10-05 01:16:00
# Entry Price : 14516.079, Stop Price : 14520.189, Take Profit Price : 14511.969
# TOTAL RR : -9.449703657951224 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 01:30:00 , Entry Time : 2021-10-05 01:32:00 , Exit Time : 2021-10-05 01:33:00
# Entry Price : 14495.009, Stop Price : 14518.529, Take Profit Price : 14471.489
# TOTAL RR : -9.740519984481837 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 01:40:00 , Entry Time : 2021-10-05 01:44:00 , Exit Time : 2021-10-05 01:50:00
# Entry Price : 14495.219, Stop Price : 14505.869, Take Profit Price : 14484.568999999998
# TOTAL RR : -10.740519984481837 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 01:53:00 , Entry Time : 2021-10-05 02:00:00 , Exit Time : 2021-10-05 02:20:00
# Entry Price : 14489.389, Stop Price : 14506.899, Take Profit Price : 14471.878999999999
# TOTAL RR : -9.740519984481837 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 02:20:00 , Entry Time : 2021-10-05 02:22:00 , Exit Time : 2021-10-05 02:25:00
# Entry Price : 14471.509, Stop Price : 14505.989, Take Profit Price : 14437.029
# TOTAL RR : -9.915926016964457 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 02:52:00 , Entry Time : 2021-10-05 02:54:00 , Exit Time : 2021-10-05 02:57:00
# Entry Price : 14449.679, Stop Price : 14469.099, Take Profit Price : 14430.259
# TOTAL RR : -10.049293679168377 Drawdown : 12.29
#
#
# LONG
# FVG Time : 2021-10-05 03:00:00 , Entry Time : 2021-10-05 03:03:00 , Exit Time : 2021-10-05 03:05:00
# Entry Price : 14450.039, Stop Price : 14436.829, Take Profit Price : 14463.249000000002
# TOTAL RR : -10.385402687495416 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 03:06:00 , Entry Time : 2021-10-05 03:11:00 , Exit Time : 2021-10-05 03:40:00
# Entry Price : 14438.099, Stop Price : 14456.799, Take Profit Price : 14419.399
# TOTAL RR : -10.964012313163828 Drawdown : 12.29
#
#
# LONG
# FVG Time : 2021-10-05 03:41:00 , Entry Time : 2021-10-05 03:44:00 , Exit Time : 2021-10-05 03:52:00
# Entry Price : 14453.299, Stop Price : 14422.859, Take Profit Price : 14483.739000000001
# TOTAL RR : -9.964012313163828 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 03:57:00 , Entry Time : 2021-10-05 04:02:00 , Exit Time : 2021-10-05 04:04:00
# Entry Price : 14475.599, Stop Price : 14488.589, Take Profit Price : 14462.609
# TOTAL RR : -10.545228633410124 Drawdown : 12.29
#
#
# LONG
# FVG Time : 2021-10-05 04:05:00 , Entry Time : 2021-10-05 04:07:00 , Exit Time : 2021-10-05 04:23:00
# Entry Price : 14487.289, Stop Price : 14458.627, Take Profit Price : 14515.951000000001
# TOTAL RR : -10.908776187663141 Drawdown : 12.29
#
#
# LONG
# FVG Time : 2021-10-05 04:30:00 , Entry Time : 2021-10-05 04:34:00 , Exit Time : 2021-10-05 05:33:00
# Entry Price : 14504.789, Stop Price : 14473.299, Take Profit Price : 14536.279
# TOTAL RR : -11.215540239743165 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 05:33:00 , Entry Time : 2021-10-05 05:36:00 , Exit Time : 2021-10-05 05:38:00
# Entry Price : 14499.659, Stop Price : 14520.089, Take Profit Price : 14479.229
# TOTAL RR : -11.684947973468079 Drawdown : 12.29
#
#
# LONG
# FVG Time : 2021-10-05 05:39:00 , Entry Time : 2021-10-05 05:46:00 , Exit Time : 2021-10-05 06:14:00
# Entry Price : 14510.887, Stop Price : 14490.549, Take Profit Price : 14531.225
# TOTAL RR : -11.944462183321571 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 06:14:00 , Entry Time : 2021-10-05 06:16:00 , Exit Time : 2021-10-05 06:46:00
# Entry Price : 14508.789, Stop Price : 14527.689, Take Profit Price : 14489.889000000001
# TOTAL RR : -12.341816680676088 Drawdown : 12.29
#
#
# SHORT
# FVG Time : 2021-10-05 06:49:00 , Entry Time : 2021-10-05 06:51:00 , Exit Time : 2021-10-05 07:00:00
# Entry Price : 14508.769, Stop Price : 14518.399, Take Profit Price : 14499.139000000001
# TOTAL RR : -13.012637033739397 Drawdown : 12.34
#
#
# SHORT
# FVG Time : 2021-10-05 07:11:00 , Entry Time : 2021-10-05 07:16:00 , Exit Time : 2021-10-05 07:21:00
# Entry Price : 14509.069, Stop Price : 14520.809, Take Profit Price : 14497.329
# TOTAL RR : -13.211103813977894 Drawdown : 13.01
#
#
# LONG
# FVG Time : 2021-10-05 07:37:00 , Entry Time : 2021-10-05 07:40:00 , Exit Time : 2021-10-05 07:41:00
# Entry Price : 14501.109, Stop Price : 14495.549, Take Profit Price : 14506.669
# TOTAL RR : -13.389161367934706 Drawdown : 13.21
#
#
# LONG
# FVG Time : 2021-10-05 07:47:00 , Entry Time : 2021-10-05 07:53:00 , Exit Time : 2021-10-05 07:56:00
# Entry Price : 14506.149, Stop Price : 14492.199, Take Profit Price : 14520.098999999998
# TOTAL RR : -13.81138359015692 Drawdown : 13.39
#
#
# SHORT
# FVG Time : 2021-10-05 07:56:00 , Entry Time : 2021-10-05 07:59:00 , Exit Time : 2021-10-05 08:00:00
# Entry Price : 14502.239, Stop Price : 14511.799, Take Profit Price : 14492.678999999998
# TOTAL RR : -14.489207857939208 Drawdown : 13.81
#
#
# SHORT
# FVG Time : 2021-10-05 08:16:00 , Entry Time : 2021-10-05 08:18:00 , Exit Time : 2021-10-05 08:21:00
# Entry Price : 14469.519, Stop Price : 14512.849, Take Profit Price : 14426.189
# TOTAL RR : -14.789461723621189 Drawdown : 14.49
#
#
# LONG
# FVG Time : 2021-10-05 08:28:00 , Entry Time : 2021-10-05 08:30:00 , Exit Time : 2021-10-05 08:31:00
# Entry Price : 14494.239, Stop Price : 14464.129, Take Profit Price : 14524.348999999998
# TOTAL RR : -14.874815426709858 Drawdown : 14.79
#
#
# LONG
# FVG Time : 2021-10-05 08:41:00 , Entry Time : 2021-10-05 08:43:00 , Exit Time : 2021-10-05 09:07:00
# Entry Price : 14500.879, Stop Price : 14479.139, Take Profit Price : 14522.619000000002
# TOTAL RR : -13.874815426709858 Drawdown : 14.87
#
#
# LONG
# FVG Time : 2021-10-05 09:11:00 , Entry Time : 2021-10-05 09:19:00 , Exit Time : 2021-10-05 09:35:00
# Entry Price : 14527.209, Stop Price : 14490.629, Take Profit Price : 14563.789
# TOTAL RR : -14.089140194342448 Drawdown : 14.87
#
#
# LONG
# FVG Time : 2021-10-05 10:01:00 , Entry Time : 2021-10-05 10:03:00 , Exit Time : 2021-10-05 10:04:00
# Entry Price : 14490.229, Stop Price : 14477.299, Take Profit Price : 14503.158999999998
# TOTAL RR : -14.233765097668126 Drawdown : 14.87
#
#
# LONG
# FVG Time : 2021-10-05 10:15:00 , Entry Time : 2021-10-05 10:17:00 , Exit Time : 2021-10-05 10:25:00
# Entry Price : 14520.129, Stop Price : 14477.299, Take Profit Price : 14562.959
# TOTAL RR : -14.422184429911916 Drawdown : 14.87
#
#
# SHORT
# FVG Time : 2021-10-05 10:25:00 , Entry Time : 2021-10-05 10:27:00 , Exit Time : 2021-10-05 10:28:00
# Entry Price : 14512.179, Stop Price : 14526.399, Take Profit Price : 14497.959
# TOTAL RR : -14.529779366620827 Drawdown : 14.87
#
#
# LONG
# FVG Time : 2021-10-05 10:30:00 , Entry Time : 2021-10-05 10:32:00 , Exit Time : 2021-10-05 12:53:00
# Entry Price : 14532.269, Stop Price : 14502.579, Take Profit Price : 14561.959
# TOTAL RR : -15.188587045974117 Drawdown : 14.87
#
#
# LONG
# FVG Time : 2021-10-05 12:56:00 , Entry Time : 2021-10-05 13:00:00 , Exit Time : 2021-10-05 13:23:00
# Entry Price : 14522.879, Stop Price : 14512.589, Take Profit Price : 14533.169000000002
# TOTAL RR : -15.79208558824821 Drawdown : 15.19
#
#
# LONG
# FVG Time : 2021-10-05 13:28:00 , Entry Time : 2021-10-05 13:30:00 , Exit Time : 2021-10-05 14:30:00
# Entry Price : 14529.579, Stop Price : 14506.049, Take Profit Price : 14553.108999999999
# TOTAL RR : -16.058128937164508 Drawdown : 15.79
#
#
# LONG
# FVG Time : 2021-10-05 15:31:00 , Entry Time : 2021-10-05 15:33:00 , Exit Time : 2021-10-05 15:52:00
# Entry Price : 14552.059, Stop Price : 14507.029, Take Profit Price : 14597.088999999998
# TOTAL RR : -15.058128937164508 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-05 16:19:00 , Entry Time : 2021-10-05 16:21:00 , Exit Time : 2021-10-05 16:22:00
# Entry Price : 14629.799, Stop Price : 14641.039, Take Profit Price : 14618.559000000001
# TOTAL RR : -15.701367371328182 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-05 16:26:00 , Entry Time : 2021-10-05 16:32:00 , Exit Time : 2021-10-05 16:34:00
# Entry Price : 14631.599, Stop Price : 14617.609, Take Profit Price : 14645.589
# TOTAL RR : -14.701367371328182 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-05 17:06:00 , Entry Time : 2021-10-05 17:08:00 , Exit Time : 2021-10-05 17:24:00
# Entry Price : 14714.569, Stop Price : 14669.679, Take Profit Price : 14759.458999999999
# TOTAL RR : -14.986731594986004 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-05 17:58:00 , Entry Time : 2021-10-05 18:00:00 , Exit Time : 2021-10-05 18:10:00
# Entry Price : 14705.609, Stop Price : 14676.349, Take Profit Price : 14734.869
# TOTAL RR : -13.986731594986004 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-05 18:20:00 , Entry Time : 2021-10-05 18:22:00 , Exit Time : 2021-10-05 18:39:00
# Entry Price : 14729.849, Stop Price : 14744.819, Take Profit Price : 14714.879
# TOTAL RR : -12.986731594986004 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-05 18:48:00 , Entry Time : 2021-10-05 18:51:00 , Exit Time : 2021-10-05 18:53:00
# Entry Price : 14733.569, Stop Price : 14713.759, Take Profit Price : 14753.378999999999
# TOTAL RR : -13.365328263335332 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-05 19:00:00 , Entry Time : 2021-10-05 19:08:00 , Exit Time : 2021-10-05 19:11:00
# Entry Price : 14726.379, Stop Price : 14740.899, Take Profit Price : 14711.859000000002
# TOTAL RR : -14.03681586664118 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-05 19:11:00 , Entry Time : 2021-10-05 19:13:00 , Exit Time : 2021-10-05 19:14:00
# Entry Price : 14731.109, Stop Price : 14716.159, Take Profit Price : 14746.059000000001
# TOTAL RR : -14.359892789718083 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-05 19:23:00 , Entry Time : 2021-10-05 19:28:00 , Exit Time : 2021-10-05 19:29:00
# Entry Price : 14732.709, Stop Price : 14716.719, Take Profit Price : 14748.699000000002
# TOTAL RR : -14.598166710918893 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-05 19:32:00 , Entry Time : 2021-10-05 19:37:00 , Exit Time : 2021-10-05 19:38:00
# Entry Price : 14733.059, Stop Price : 14743.209, Take Profit Price : 14722.908999999998
# TOTAL RR : -14.846442572987865 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-05 19:54:00 , Entry Time : 2021-10-05 19:58:00 , Exit Time : 2021-10-05 20:00:00
# Entry Price : 14746.579, Stop Price : 14758.399, Take Profit Price : 14734.759
# TOTAL RR : -15.435275060297604 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-05 20:05:00 , Entry Time : 2021-10-05 20:12:00 , Exit Time : 2021-10-05 20:16:00
# Entry Price : 14754.259, Stop Price : 14764.669, Take Profit Price : 14743.849
# TOTAL RR : -14.435275060297604 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-05 20:21:00 , Entry Time : 2021-10-05 20:23:00 , Exit Time : 2021-10-05 20:25:00
# Entry Price : 14738.799, Stop Price : 14764.669, Take Profit Price : 14712.929000000002
# TOTAL RR : -14.72673234672974 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-05 21:13:00 , Entry Time : 2021-10-05 21:15:00 , Exit Time : 2021-10-05 21:18:00
# Entry Price : 14757.219, Stop Price : 14741.069, Take Profit Price : 14773.368999999999
# TOTAL RR : -15.381840705862878 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-05 21:23:00 , Entry Time : 2021-10-05 21:28:00 , Exit Time : 2021-10-05 21:52:00
# Entry Price : 14724.269, Stop Price : 14759.807, Take Profit Price : 14688.731
# TOTAL RR : -14.381840705862878 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-06 01:17:00 , Entry Time : 2021-10-06 01:20:00 , Exit Time : 2021-10-06 02:22:00
# Entry Price : 14665.049, Stop Price : 14685.109, Take Profit Price : 14644.989000000001
# TOTAL RR : -14.489517674955595 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-06 02:24:00 , Entry Time : 2021-10-06 02:26:00 , Exit Time : 2021-10-06 02:39:00
# Entry Price : 14671.799, Stop Price : 14647.159, Take Profit Price : 14696.439000000002
# TOTAL RR : -14.688787155475133 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-06 03:19:00 , Entry Time : 2021-10-06 03:21:00 , Exit Time : 2021-10-06 03:29:00
# Entry Price : 14634.329, Stop Price : 14624.039, Take Profit Price : 14644.618999999999
# TOTAL RR : -15.363228360528694 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-06 03:53:00 , Entry Time : 2021-10-06 03:55:00 , Exit Time : 2021-10-06 03:59:00
# Entry Price : 14582.099, Stop Price : 14625.089, Take Profit Price : 14539.109
# TOTAL RR : -15.596305820403096 Drawdown : 16.06
#
#
# LONG
# FVG Time : 2021-10-06 04:24:00 , Entry Time : 2021-10-06 04:32:00 , Exit Time : 2021-10-06 04:45:00
# Entry Price : 14601.059, Stop Price : 14587.549, Take Profit Price : 14614.568999999998
# TOTAL RR : -16.42828213424478 Drawdown : 16.06
#
#
# SHORT
# FVG Time : 2021-10-06 04:46:00 , Entry Time : 2021-10-06 04:50:00 , Exit Time : 2021-10-06 05:30:00
# Entry Price : 14578.809, Stop Price : 14607.089, Take Profit Price : 14550.528999999999
# TOTAL RR : -17.220007735376345 Drawdown : 16.43
#
#
# SHORT
# FVG Time : 2021-10-06 05:32:00 , Entry Time : 2021-10-06 05:34:00 , Exit Time : 2021-10-06 05:37:00
# Entry Price : 14591.199, Stop Price : 14601.399, Take Profit Price : 14580.999000000002
# TOTAL RR : -17.437654794199833 Drawdown : 17.22
#
#
# SHORT
# FVG Time : 2021-10-06 05:40:00 , Entry Time : 2021-10-06 05:42:00 , Exit Time : 2021-10-06 05:43:00
# Entry Price : 14592.819, Stop Price : 14601.399, Take Profit Price : 14584.239
# TOTAL RR : -17.659100015645013 Drawdown : 17.44
#
#
# LONG
# FVG Time : 2021-10-06 05:53:00 , Entry Time : 2021-10-06 06:00:00 , Exit Time : 2021-10-06 06:08:00
# Entry Price : 14600.769, Stop Price : 14588.839, Take Profit Price : 14612.699
# TOTAL RR : -17.918110912543593 Drawdown : 17.66
#
#
# SHORT
# ...
# TOTAL RR : -71.61231339180802 Drawdown : 71.56
#
#
# LONG
# FVG Time : 2021-12-15 10:17:00 , Entry Time : 2021-12-15 10:23:00 , Exit Time : 2021-12-15 10:35:00
# Entry Price : 15919.519, Stop Price : 15906.119, Take Profit Price : 15932.919
# TOTAL RR : -70.61231339180802 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 10:44:00 , Entry Time : 2021-12-15 10:51:00 , Exit Time : 2021-12-15 10:57:00
# Entry Price : 15949.119, Stop Price : 15922.309, Take Profit Price : 15975.929000000002
# TOTAL RR : -70.89168675995421 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 11:07:00 , Entry Time : 2021-12-15 11:11:00 , Exit Time : 2021-12-15 11:13:00
# Entry Price : 15953.649, Stop Price : 15939.069, Take Profit Price : 15968.229
# TOTAL RR : -70.89511611523537 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 11:18:00 , Entry Time : 2021-12-15 11:21:00 , Exit Time : 2021-12-15 11:24:00
# Entry Price : 15956.689, Stop Price : 15945.349, Take Profit Price : 15968.029
# TOTAL RR : -71.05384627396562 Drawdown : 71.61
#
#
# SHORT
# FVG Time : 2021-12-15 11:25:00 , Entry Time : 2021-12-15 11:27:00 , Exit Time : 2021-12-15 11:33:00
# Entry Price : 15950.849, Stop Price : 15964.819, Take Profit Price : 15936.879
# TOTAL RR : -70.05384627396562 Drawdown : 71.61
#
#
# SHORT
# FVG Time : 2021-12-15 11:36:00 , Entry Time : 2021-12-15 11:39:00 , Exit Time : 2021-12-15 11:52:00
# Entry Price : 15930.339, Stop Price : 15964.819, Take Profit Price : 15895.859
# TOTAL RR : -70.194217503664 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 11:53:00 , Entry Time : 2021-12-15 11:57:00 , Exit Time : 2021-12-15 12:09:00
# Entry Price : 15939.339, Stop Price : 15921.899, Take Profit Price : 15956.779
# TOTAL RR : -70.71256612751715 Drawdown : 71.61
#
#
# SHORT
# FVG Time : 2021-12-15 12:16:00 , Entry Time : 2021-12-15 12:18:00 , Exit Time : 2021-12-15 14:00:00
# Entry Price : 15885.069, Stop Price : 15939.999, Take Profit Price : 15830.139
# TOTAL RR : -71.06901979582226 Drawdown : 71.61
#
#
# SHORT
# FVG Time : 2021-12-15 14:20:00 , Entry Time : 2021-12-15 14:25:00 , Exit Time : 2021-12-15 14:30:00
# Entry Price : 15879.419, Stop Price : 15894.659, Take Profit Price : 15864.179
# TOTAL RR : -70.06901979582226 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 15:01:00 , Entry Time : 2021-12-15 15:04:00 , Exit Time : 2021-12-15 15:32:00
# Entry Price : 15894.839, Stop Price : 15871.509, Take Profit Price : 15918.169
# TOTAL RR : -69.06901979582226 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 15:32:00 , Entry Time : 2021-12-15 15:34:00 , Exit Time : 2021-12-15 15:37:00
# Entry Price : 15919.069, Stop Price : 15897.239, Take Profit Price : 15940.899
# TOTAL RR : -69.26324792225377 Drawdown : 71.61
#
#
# SHORT
# FVG Time : 2021-12-15 15:37:00 , Entry Time : 2021-12-15 15:42:00 , Exit Time : 2021-12-15 15:43:00
# Entry Price : 15916.069, Stop Price : 15921.669, Take Profit Price : 15910.469
# TOTAL RR : -69.3775336365397 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 15:47:00 , Entry Time : 2021-12-15 15:49:00 , Exit Time : 2021-12-15 15:50:00
# Entry Price : 15914.599, Stop Price : 15904.839, Take Profit Price : 15924.359
# TOTAL RR : -69.4758942922775 Drawdown : 71.61
#
#
# SHORT
# FVG Time : 2021-12-15 15:53:00 , Entry Time : 2021-12-15 15:55:00 , Exit Time : 2021-12-15 16:01:00
# Entry Price : 15909.819, Stop Price : 15924.499, Take Profit Price : 15895.139
# TOTAL RR : -69.84987249391236 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 16:21:00 , Entry Time : 2021-12-15 16:23:00 , Exit Time : 2021-12-15 16:30:00
# Entry Price : 15927.559, Stop Price : 15892.739, Take Profit Price : 15962.378999999999
# TOTAL RR : -68.84987249391236 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 16:30:00 , Entry Time : 2021-12-15 16:34:00 , Exit Time : 2021-12-15 16:40:00
# Entry Price : 15939.309, Stop Price : 15909.769, Take Profit Price : 15968.848999999998
# TOTAL RR : -69.26084067265305 Drawdown : 71.61
#
#
# SHORT
# FVG Time : 2021-12-15 16:43:00 , Entry Time : 2021-12-15 16:45:00 , Exit Time : 2021-12-15 16:51:00
# Entry Price : 15915.619, Stop Price : 15970.559, Take Profit Price : 15860.679000000002
# TOTAL RR : -69.32618468430212 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 17:02:00 , Entry Time : 2021-12-15 17:06:00 , Exit Time : 2021-12-15 17:25:00
# Entry Price : 15910.039, Stop Price : 15892.279, Take Profit Price : 15927.799
# TOTAL RR : -69.45737837799581 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 17:28:00 , Entry Time : 2021-12-15 17:30:00 , Exit Time : 2021-12-15 17:31:00
# Entry Price : 15921.729, Stop Price : 15901.109, Take Profit Price : 15942.348999999998
# TOTAL RR : -70.45737837799581 Drawdown : 71.61
#
#
# SHORT
# FVG Time : 2021-12-15 17:31:00 , Entry Time : 2021-12-15 17:34:00 , Exit Time : 2021-12-15 17:35:00
# Entry Price : 15875.889, Stop Price : 15931.789, Take Profit Price : 15819.988999999998
# TOTAL RR : -71.26632292182407 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 17:35:00 , Entry Time : 2021-12-15 17:40:00 , Exit Time : 2021-12-15 17:41:00
# Entry Price : 15894.909, Stop Price : 15863.879, Take Profit Price : 15925.938999999998
# TOTAL RR : -71.59181438170164 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 17:56:00 , Entry Time : 2021-12-15 17:58:00 , Exit Time : 2021-12-15 17:59:00
# Entry Price : 15849.589, Stop Price : 15828.759, Take Profit Price : 15870.419
# TOTAL RR : -71.9230673821817 Drawdown : 71.61
#
#
# LONG
# FVG Time : 2021-12-15 18:21:00 , Entry Time : 2021-12-15 18:24:00 , Exit Time : 2021-12-15 18:30:00
# Entry Price : 15872.759, Stop Price : 15828.749, Take Profit Price : 15916.769
# TOTAL RR : -72.45726415564228 Drawdown : 71.92
#
#
# SHORT
# FVG Time : 2021-12-15 18:44:00 , Entry Time : 2021-12-15 18:46:00 , Exit Time : 2021-12-15 18:50:00
# Entry Price : 15887.849, Stop Price : 15912.659, Take Profit Price : 15863.039
# TOTAL RR : -71.45726415564228 Drawdown : 72.46
#
#
# SHORT
# FVG Time : 2021-12-15 18:54:00 , Entry Time : 2021-12-15 19:04:00 , Exit Time : 2021-12-15 19:31:00
# Entry Price : 15850.109, Stop Price : 15902.799, Take Profit Price : 15797.419
# TOTAL RR : -70.45726415564228 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-15 19:49:00 , Entry Time : 2021-12-15 19:51:00 , Exit Time : 2021-12-15 20:07:00
# Entry Price : 15782.299, Stop Price : 15767.039, Take Profit Price : 15797.559000000001
# TOTAL RR : -71.24232313336188 Drawdown : 72.46
#
#
# SHORT
# FVG Time : 2021-12-15 20:42:00 , Entry Time : 2021-12-15 20:51:00 , Exit Time : 2021-12-15 20:52:00
# Entry Price : 15789.529, Stop Price : 15808.699, Take Profit Price : 15770.359
# TOTAL RR : -71.36804039992421 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-15 20:52:00 , Entry Time : 2021-12-15 20:57:00 , Exit Time : 2021-12-15 21:28:00
# Entry Price : 15794.579, Stop Price : 15772.899, Take Profit Price : 15816.259
# TOTAL RR : -70.36804039992421 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-15 21:32:00 , Entry Time : 2021-12-15 21:38:00 , Exit Time : 2021-12-15 21:50:00
# Entry Price : 15817.949, Stop Price : 15797.499, Take Profit Price : 15838.399000000001
# TOTAL RR : -70.78857829723472 Drawdown : 72.46
#
#
# SHORT
# FVG Time : 2021-12-15 22:27:00 , Entry Time : 2021-12-15 22:29:00 , Exit Time : 2021-12-15 22:31:00
# Entry Price : 15913.937, Stop Price : 16008.899, Take Profit Price : 15818.975
# TOTAL RR : -70.98773164278347 Drawdown : 72.46
#
#
# SHORT
# FVG Time : 2021-12-15 22:43:00 , Entry Time : 2021-12-15 22:46:00 , Exit Time : 2021-12-15 22:48:00
# Entry Price : 15975.879, Stop Price : 16000.519, Take Profit Price : 15951.239000000001
# TOTAL RR : -71.66102709732887 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-15 22:53:00 , Entry Time : 2021-12-15 22:55:00 , Exit Time : 2021-12-15 23:14:00
# Entry Price : 16010.169, Stop Price : 15891.849, Take Profit Price : 16128.489
# TOTAL RR : -70.66102709732887 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-15 23:22:00 , Entry Time : 2021-12-15 23:24:00 , Exit Time : 2021-12-15 23:25:00
# Entry Price : 16210.529, Stop Price : 16024.309, Take Profit Price : 16396.749000000003
# TOTAL RR : -70.7407177857619 Drawdown : 72.46
#
#
# SHORT
# FVG Time : 2021-12-15 23:25:00 , Entry Time : 2021-12-15 23:27:00 , Exit Time : 2021-12-15 23:34:00
# Entry Price : 16201.429, Stop Price : 16239.429, Take Profit Price : 16163.429
# TOTAL RR : -71.47913883839347 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-15 23:35:00 , Entry Time : 2021-12-15 23:41:00 , Exit Time : 2021-12-15 23:42:00
# Entry Price : 16239.799, Stop Price : 16185.139, Take Profit Price : 16294.459000000003
# TOTAL RR : -72.01243558189879 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-15 23:52:00 , Entry Time : 2021-12-15 23:54:00 , Exit Time : 2021-12-16 08:48:00
# Entry Price : 16266.169, Stop Price : 16177.319, Take Profit Price : 16355.019
# TOTAL RR : -71.01243558189879 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-16 09:19:00 , Entry Time : 2021-12-16 09:21:00 , Exit Time : 2021-12-16 09:23:00
# Entry Price : 16372.999, Stop Price : 16352.219, Take Profit Price : 16393.779000000002
# TOTAL RR : -71.16787350297672 Drawdown : 72.46
#
#
# LONG
# FVG Time : 2021-12-16 09:25:00 , Entry Time : 2021-12-16 09:29:00 , Exit Time : 2021-12-16 09:30:00
# Entry Price : 16372.219, Stop Price : 16362.759, Take Profit Price : 16381.678999999998
# TOTAL RR : -71.67527308014371 Drawdown : 72.46
#
#
# SHORT
# FVG Time : 2021-12-16 09:30:00 , Entry Time : 2021-12-16 09:38:00 , Exit Time : 2021-12-16 09:44:00
# Entry Price : 16369.159, Stop Price : 16379.209, Take Profit Price : 16359.108999999999
# TOTAL RR : -72.56781039357656 Drawdown : 72.46
#
#
# SHORT
# FVG Time : 2021-12-16 09:48:00 , Entry Time : 2021-12-16 09:52:00 , Exit Time : 2021-12-16 09:54:00
# Entry Price : 16374.159, Stop Price : 16379.399, Take Profit Price : 16368.919
# TOTAL RR : -73.56781039357656 Drawdown : 72.57
#
#
# LONG
# FVG Time : 2021-12-16 10:12:00 , Entry Time : 2021-12-16 10:14:00 , Exit Time : 2021-12-16 10:28:00
# Entry Price : 16402.319, Stop Price : 16373.109, Take Profit Price : 16431.529
# TOTAL RR : -72.56781039357656 Drawdown : 73.57
#
#
# SHORT
# FVG Time : 2021-12-16 10:34:00 , Entry Time : 2021-12-16 10:43:00 , Exit Time : 2021-12-16 10:44:00
# Entry Price : 16425.419, Stop Price : 16431.889, Take Profit Price : 16418.949000000004
# TOTAL RR : -72.86456464396281 Drawdown : 73.57
#
#
# SHORT
# FVG Time : 2021-12-16 10:54:00 , Entry Time : 2021-12-16 10:59:00 , Exit Time : 2021-12-16 11:13:00
# Entry Price : 16402.139, Stop Price : 16428.389, Take Profit Price : 16375.889
# TOTAL RR : -71.86456464396281 Drawdown : 73.57
#
#
# LONG
# FVG Time : 2021-12-16 11:23:00 , Entry Time : 2021-12-16 11:29:00 , Exit Time : 2021-12-16 11:37:00
# Entry Price : 16383.399, Stop Price : 16365.389, Take Profit Price : 16401.409
# TOTAL RR : -70.86456464396281 Drawdown : 73.57
#
#
# LONG
# FVG Time : 2021-12-16 11:38:00 , Entry Time : 2021-12-16 11:40:00 , Exit Time : 2021-12-16 12:00:00
# Entry Price : 16404.739, Stop Price : 16365.879, Take Profit Price : 16443.599000000002
# TOTAL RR : -71.04933047000502 Drawdown : 73.57
#
#
# SHORT
# FVG Time : 2021-12-16 12:08:00 , Entry Time : 2021-12-16 12:11:00 , Exit Time : 2021-12-16 12:12:00
# Entry Price : 16378.779, Stop Price : 16413.059, Take Profit Price : 16344.499
# TOTAL RR : -71.16508309544255 Drawdown : 73.57
#
#
# LONG
# FVG Time : 2021-12-16 12:32:00 , Entry Time : 2021-12-16 12:35:00 , Exit Time : 2021-12-16 12:36:00
# Entry Price : 16376.619, Stop Price : 16367.819, Take Profit Price : 16385.419
# TOTAL RR : -71.8525830954426 Drawdown : 73.57
#
#
# SHORT
# FVG Time : 2021-12-16 12:36:00 , Entry Time : 2021-12-16 12:39:00 , Exit Time : 2021-12-16 12:44:00
# Entry Price : 16373.889, Stop Price : 16382.619, Take Profit Price : 16365.158999999998
# TOTAL RR : -72.52383166359834 Drawdown : 73.57
#
#
# LONG
# FVG Time : 2021-12-16 12:46:00 , Entry Time : 2021-12-16 12:48:00 , Exit Time : 2021-12-16 12:49:00
# Entry Price : 16382.679, Stop Price : 16368.089, Take Profit Price : 16397.269
# TOTAL RR : -72.62938341137085 Drawdown : 73.57
#
#
# SHORT
# FVG Time : 2021-12-16 12:49:00 , Entry Time : 2021-12-16 12:51:00 , Exit Time : 2021-12-16 12:59:00
# Entry Price : 16380.619, Stop Price : 16387.109, Take Profit Price : 16374.129
# TOTAL RR : -73.24571623109324 Drawdown : 73.57
#
#
# SHORT
# FVG Time : 2021-12-16 13:21:00 , Entry Time : 2021-12-16 13:25:00 , Exit Time : 2021-12-16 13:43:00
# Entry Price : 16386.859, Stop Price : 16396.789, Take Profit Price : 16376.929
# TOTAL RR : -74.24571623109324 Drawdown : 73.57
#
#
# LONG
# FVG Time : 2021-12-16 13:43:00 , Entry Time : 2021-12-16 13:47:00 , Exit Time : 2021-12-16 13:55:00
# Entry Price : 16395.179, Stop Price : 16385.199, Take Profit Price : 16405.159
# TOTAL RR : -73.24571623109324 Drawdown : 74.25
#
#
# LONG
# FVG Time : 2021-12-16 13:57:00 , Entry Time : 2021-12-16 14:04:00 , Exit Time : 2021-12-16 14:05:00
# Entry Price : 16408.759, Stop Price : 16393.339, Take Profit Price : 16424.178999999996
# TOTAL RR : -73.40330377973117 Drawdown : 74.25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6604\540032976.py in ?()
#      96
#      97
#      98                         break
#      99
# --> 100         elif check_for_fvg(df, current_index) == -1:
#     101             """ SHORT POSITION  """
#     102
#     103             fvg_index = current_index - 1
#
# ~\AppData\Local\Temp\ipykernel_6604\439227841.py in ?(df, current_index)
#      18
#      19     fvg_body_threshold = 1
#      20     fvg_wick_threshold = 1
#      21
# ---> 22     current_body = abs(df.iloc[current_index - 1]['Close'] - df.iloc[current_index - 1]['Open'])
#      23
#      24     # Check for a Bullish FVG (current candle's low is higher than the previous candle's high)
#      25     if current_body > fvg_body_threshold and current_low - prev_2_high > fvg_wick_threshold:
#
# c:\Users\Nasip-PC\anaconda3\envs\olympus\lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    1187             axis = self.axis or 0
#    1188
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#
# c:\Users\Nasip-PC\anaconda3\envs\olympus\lib\site-packages\pandas\core\indexing.py in ?(self, key, axis)
#    1750
#    1751             # validate the location
#    1752             self._validate_integer(key, axis)
#    1753
# -> 1754             return self.obj._ixs(key, axis=axis)
#
# c:\Users\Nasip-PC\anaconda3\envs\olympus\lib\site-packages\pandas\core\frame.py in ?(self, i, axis)
#    3996             new_mgr = self._mgr.fast_xs(i)
#    3997
#    3998             # if we are a copy, mark as such
#    3999             copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
# -> 4000             result = self._constructor_sliced_from_mgr(new_mgr, axes=new_mgr.axes)
#    4001             result._name = self.index[i]
#    4002             result = result.__finalize__(self)
#    4003             result._set_is_copy(self, copy=copy)
#
# c:\Users\Nasip-PC\anaconda3\envs\olympus\lib\site-packages\pandas\core\frame.py in ?(self, mgr, axes)
#     678     def _constructor_sliced_from_mgr(self, mgr, axes) -> Series:
#     679         ser = Series._from_mgr(mgr, axes)
# --> 680         ser._name = None  # caller is responsible for setting real name
#     681
#     682         if type(self) is DataFrame:
#     683             # This would also work `if self._constructor_sliced is Series`, but
#
# c:\Users\Nasip-PC\anaconda3\envs\olympus\lib\site-packages\pandas\core\generic.py in ?(self, name, value)
#    6315             pass
#    6316
#    6317         # if this fails, go on to more involved attribute setting
#    6318         # (note that this matches __getattr__, above).
# -> 6319         if name in self._internal_names_set:
#    6320             object.__setattr__(self, name, value)
#    6321         elif name in self._metadata:
#    6322             object.__setattr__(self, name, value)
#
# KeyboardInterrupt:
